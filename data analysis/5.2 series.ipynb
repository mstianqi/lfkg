# %%
import pandas as pd

df = pd.DataFrame([
    {"姓名": "小明", "语文": 90, "数学": 80},
    {"姓名": "小红", "语文": 80, "数学": 85},
    {"姓名": "小强", "语文": 70, "数学": 60}
])
s1 = pd.Series([10,20,30])
s2 = pd.Series([10,20,30], index=['a', 'b', 'c'])
s3 = pd.Series({'a':10, 'b':20, 'c':30})
s4 = df['语文']

s1.index
s1.values
s1.size
s1.dtype
s1.shape
# Out:
# (3,)
